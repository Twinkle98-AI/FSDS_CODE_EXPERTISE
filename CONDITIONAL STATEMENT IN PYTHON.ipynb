# %% [markdown]
# CONDITIONAL STATEMENT IN PYTHON

# %%
#if conditional statement

# %%
age=20
if age >=18:
    print("Eligible to vote.")
# Out:
# Eligible to vote.

# %% [markdown]
# #Short Hand if

# %% [markdown]
# short-hand if statement allows us to write a single-line if statement.

# %%
age=19
if age>18: print("Eligible to vote.")
# Out:
# Eligible to vote.

# %% [markdown]
# If else conditional statement

# %%
age=10
if age <=12:
    print("Travel for free.")
else:
    print("pay for ticket.")
# Out:
# Travel for free.

# %%
#Short hand if-else

# %% [markdown]
# the short hand if else statement allows us to write a single line if else statement.

# %%
marks = 45
res= "pass" if marks >= 40 else "Fail"
print(f"Result:{res}")
# Out:
# Result:pass

# %% [markdown]
# elif statement

# %%
age = 25
if age<=12:
    print("child.")
elif age <=19:
    print("teenager.")
elif age <= 35:
    print("young adult.")
else:
    print("adult.")
# Out:
# young adult.

# %% [markdown]
# Nested if..else conditional statement

# %%
age= 70
is_member= True

if age>=60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")
else:
    print("not eligible for a senior discount.")
# Out:
# 30% senior discount!

# %% [markdown]
# Ternary conditional statement
# - A ternary conditional statement is a compact way to erite an if-else condition in a single line. its sometimes called as a "conditional expression".

# %%
age = 20
s= "adult" if age >=18 else "minor"
print(s)
# Out:
# adult

# %% [markdown]
# Match case statement

# %%
number = 2

match number:
 case 1:
    print("One")
 case 2 | 3:
    print("Two or Three")
 case _:
    print("Other number")
# Out:
# Two or Three
