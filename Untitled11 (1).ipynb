# %% [markdown]
# kaggle task for data sciience with pandas ai
#  - https://www.kaggle.com/code/harunshimanto/pandas-with-data-science-ai

# %%
import pandas as pd

# %%
ratings = pd.read_csv(r'C:\Users\Twinkele\Downloads\archive (1)\rating.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
tags=pd.read_csv(r'C:\Users\Twinkele\Downloads\archive (1)\tag.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
ratings.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tags.head(3)
# Out:
#    userId  movieId          tag            timestamp
# 0      18     4141  Mark Waters  2009-04-24 18:19:40
# 1      65      208    dark hero  2013-05-10 01:41:18
# 2      65      353    dark hero  2013-05-10 01:41:19

# %%
movies=pd.read_csv(r'C:\Users\Twinkele\Downloads\archive (1)\movie.csv')

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
print(tags.columns)
print(ratings.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(tags.columns)
print(ratings.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
tags.head(3)
# Out:
#    userId  movieId          tag
# 0      18     4141  Mark Waters
# 1      65      208    dark hero
# 2      65      353    dark hero

# %%
tags.iloc[0]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
tags.iloc[2]
# Out:
# userId            65
# movieId          353
# tag        dark hero
# Name: 2, dtype: object

# %%
row_1=tags.iloc[1]
row
